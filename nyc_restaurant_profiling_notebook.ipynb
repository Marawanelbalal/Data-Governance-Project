# %%
from google.colab import drive
drive.mount('/content/drive')

import sys
# !{sys.executable} -m pip install ydata-profiling gdown
# Out:
# Mounted at /content/drive
# ...

# %%
import pandas as pd
from ydata_profiling import ProfileReport
import gdown

file_id = '1LuWj3kXiwlz0uTZcQo_HEfHd0Pg_bhEo'
output_path = '/content/DOHMH_Restaurant.csv'
gdown.download(f'https://drive.google.com/uc?id={file_id}', output_path, quiet=False)

df = pd.read_csv(output_path)

profile = ProfileReport(df, title="DOHMH Restaurant Inspections Data Profile", explorative=True)

profile.to_file("dohmh_restaurant_profile_report.html")

print("Data profiling report generated and saved as 'dohmh_restaurant_profile_report.html'")
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1LuWj3kXiwlz0uTZcQo_HEfHd0Pg_bhEo
# From (redirected): https://drive.google.com/uc?id=1LuWj3kXiwlz0uTZcQo_HEfHd0Pg_bhEo&confirm=t&uuid=977f6636-6676-4982-a014-fec236711ccb
# To: /content/DOHMH_Restaurant.csv
# 100%|██████████| 146M/146M [00:01<00:00, 109MB/s]
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
# Data profiling report generated and saved as 'dohmh_restaurant_profile_report.html'
